# %% [markdown]
# # Panda Lesson
# > Includes: importing pandas, panda library, panda dataframes, pandas and filtering/sorting data
# - toc: true
# - tags: [lesson]
# - type: lesson
# - week: 31

# %% [markdown]
# ## What are pandas and what is its purpose?
# - Pandas is a software library that is used in Python
# - Pandas are used for data analysis and data manipulation
#     - Pandas offer data structures and operations for manipulating numerical tables and time series.
# - Pandas is free
# ## Things you can do using pandas
# - Data Cleansing
# - Data fill
# - statistical analysis
# - Data visualization
# - Data inspection
# ## Pandas and Data analysis
# The 2 most important data structures in Pandas are:
# - Series
# - DataFrame

# %% [markdown]
# ## Dataframes

# %%
# Importing Pandas 
import pandas as pd

# %%
# Check if pandas is working
pd.__version__
# Out:
# '1.4.2'

# %% [markdown]
# ## Importing CSV data
#
# Links to find CSV data
#     - you can follow along or choose your own csv data
# - https://sports-statistics.com/sports-data-sets-for-data-modeling-visualization-predictions-machine-learning/
# - https://data.world/datasets/sports
#
# The one I am using:
# - https://www.kaggle.com/datasets/fernandol/countries-of-the-world?resource=download

# %%
data_frame = pd.read_csv("countries of the world.csv")

# %% [markdown]
# ## Creating a dataframe

# %%
countries = pd.Series(["Afghanistan","Albania","Algeria","Andorra","Angola","Anguilla"])

region = pd.Series(["Asia","Eastern Europe","Northern Africa","Western Europe","Sub-Saharan Africa","Latin America"])

pd.DataFrame({"countries": countries, "region": region})
# Out:
#      countries              region
# 0  Afghanistan                Asia
# 1      Albania      Eastern Europe
# 2      Algeria     Northern Africa
# 3      Andorra      Western Europe
# 4       Angola  Sub-Saharan Africa
# 5     Anguilla       Latin America

# %% [markdown]
# As you can see the pandas and the series function display the data nicely.

# %%
filtered_data = data_frame[data_frame['Population'] > 1000000000 ]

pd.DataFrame(filtered_data)

# only the countries above 1000000000 are being printed
# Out:
#    Country                         Region  Population  Area (sq. mi.)  \
# 42  China   ASIA (EX. NEAR EAST)           1313973713         9596960
# 94  India   ASIA (EX. NEAR EAST)           1095351995         3287590
#
#    Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# 42                      136,9                         0,15          -0,4
# 94                      333,2                         0,21         -0,07
#
#    Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 42                              24,18              5000.0         90,9
# 94                              56,29              2900.0         59,5
#
#    Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# 42             266,7       15,4      1,25     83,35     1,5     13,25
# 94              45,4       54,4      2,74     42,86     2,5     22,01
#
#    Deathrate Agriculture Industry Service
# 42      6,97       0,125    0,473   0,403
# ...

# %%
# you can use this same type of filtering and customize it to what you want
# Here is another example
filtered_data2 = data_frame[data_frame['GDP ($ per capita)'] < 10000 ]

pd.DataFrame(filtered_data2)
# Out:
#                 Country                               Region  Population  \
# 0          Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1              Albania   EASTERN EUROPE                          3581655
# 2              Algeria   NORTHERN AFRICA                        32930091
# 3       American Samoa   OCEANIA                                   57794
# 5               Angola   SUB-SAHARAN AFRICA                     12127071
# ..                  ...                                  ...         ...
# 221  Wallis and Futuna   OCEANIA                                   16025
# 222          West Bank   NEAR EAST                               2460492
# 224              Yemen   NEAR EAST                              21456188
# 225             Zambia   SUB-SAHARAN AFRICA                     11502010
# 226           Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# ## Using pandas for data analysis
#
# - Pandas allows users to easily import data from a variety of file formats, including CSV, Excel, and SQL databases. It provides  tools for data cleaning, transformation, and analysis, such as filtering, grouping, pivoting, and statistical analysis.
#
# - Pandas also integrates well with other popular visualization libraries like Matplotlib and Seaborn to create informative and visually appealing data visualizations.
#
# ### Why is pandas effective?
# - Pandas is a built in python library that is free
# - It offers a variety of tools such as:
#     - Data Handling: Pandas can handle a variety of data formats, including CSV, Excel, SQL databases, and more. It makes it easy to read and manipulate large datasets with multiple rows and columns.
#
#     - Data Cleaning: Pandas provides powerful tools for data cleaning, such as handling missing values, dealing with duplicates, and transforming data into the desired format.
#
#     - Data Transformation: Pandas provides flexible and efficient functions for data transformation, such as filtering, sorting, grouping, merging, and pivoting data.
#
#     - Data Visualization: Pandas integrates well with other popular visualization libraries like Matplotlib and Seaborn to create effective and informative data visualizations.
#
# ### Pandas in our project
#
# As explained before, pandas can be used to organzie and manipulate data. In our own project, we created an NBA statistics site that allows you to calculate/predict future outcomes such as points scored, game winners, etc. You can imagine how Pandas comes into use here. Our project uses lots of CSV data files so we use Pandas to filter and sort through to use only the data that we need. Pandas also offer fucntions that allow for statistical analysis that we will be using in our project.
